# %%
# !nvidia-smi
# Out:
# Wed May 21 06:37:56 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# # 현재 위치 확인

# %%
# 현재 위치 확인
# !pwd
# Out:
# /content

# %%
# 위치를 이동하는 명령
# %cd train
# Out:
# /content/train

# %%
# !pwd
# Out:
# /content/train

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17483, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 17483 (delta 77), reused 29 (delta 29), pack-reused 17377 (from 3)
# Receiving objects: 100% (17483/17483), 16.35 MiB | 18.36 MiB/s, done.
# Resolving deltas: 100% (11988/11988), done.

# %%
# %cd ..
# Out:
# /content

# %%
# %cd /content/data
# Out:
# /content/data

# %%
# 압축 해제
# !unzip -o data.zip
# Out:
# Archive:  data.zip
#   inflating: data.yaml
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#   inflating: test/images/fire-101_png.rf.6daab5e90a57f55aabe68cc82dce2311.jpg
#   inflating: test/images/fire-111_png.rf.059b1abb2d164039fb565a42d19a8087.jpg
#   inflating: test/images/fire-128_png.rf.c422e43bf17cf87b343e49bcff9d5920.jpg
#   inflating: test/images/fire-130_png.rf.3c5363bd93901f31698c2f493203cbb6.jpg
#   inflating: test/images/fire-13_png.rf.0b3c2670f1d1fbe1ae26660c2226a384.jpg
#   inflating: test/images/fire-144_png.rf.fdaf3fca71f07ee8ebce22c0050d66e4.jpg
#   inflating: test/images/fire-155_png.rf.ddd8e1b3f39e7b76dd56f0119b3543b1.jpg
#   inflating: test/images/fire-746_png.rf.dfc3bd3f35a639b73a989a7c6e6e9de0.jpg
#   inflating: test/images/non_fire-128_png.rf.a7c244adadf0ae7a68881c32ee528eb1.jpg
#   inflating: test/images/non_fire-1_png.rf.0b8c934fc136fde64eb652e371c3f13b.jpg
#   inflating: test/labels/fire-101_png.rf.6daab5e90a57f55aabe68cc82dce2311.txt
# ...

# %% [markdown]
# # 라이브러리 설치하기

# %%
# %cd /content/train/yolov5/
# Out:
# /content/train/yolov5

# %%
# 라이브러리 한번에 설치하는 방법
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 129.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 63.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 55.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !python train.py --img 415 --batch 16 --epochs 300 --data /content/data/data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name fire_yolov5s_results
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-05-21 06:50:20.836823: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747810220.870626    5193 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747810220.882664    5193 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %% [markdown]
# # 파일 압축하고 다운로드하기

# %%
# !zip -r /content/fire_result.zip /content/train/yolov5/runs/train/fire_yolov5s_results/
